# %%
import pandas as pd
import numpy as np
dados = pd.read_csv("data.csv")

# %%
print (dados.describe())
# Out:
#                   ID       special           age     height_cm     weight_kg  \
# count   17994.000000  17994.000000  17994.000000  17994.000000  17994.000000
# mean   207791.796543   1594.417306     25.120151    181.271980     75.400856
# std     32328.527723    271.587232      4.617428      6.690392      6.994824
# min        16.000000    728.000000     16.000000    155.000000     49.000000
# 25%    192621.250000   1450.250000     21.000000    177.000000     70.000000
# 50%    214186.000000   1634.000000     25.000000    181.000000     75.000000
# 75%    231615.750000   1785.000000     28.000000    186.000000     80.000000
# max    241489.000000   2291.000000     47.000000    205.000000    110.000000
#
#           eur_value       eur_wage  eur_release_clause       overall  \
# count  1.799400e+04   17994.000000        1.650000e+04  17994.000000
# mean   2.370511e+06   11503.834612        4.449111e+06     66.253029
# ...
